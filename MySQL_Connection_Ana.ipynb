# %% [markdown]
# # Creating a connection bewteen the Jupyter Notebooks and the MySQL Database 📤 📥
# After creating the database in MySQL to manage the information we can create a connection to the Notebooks.

# %% [markdown]
# ---
# ## 1.&nbsp;Import libraries and files 💾

# %%
# Local
import pandas as pd
# Files
diphteria = pd.read_csv('diphteria.csv', index_col = 0)
diphteria_data = diphteria.copy()
diphteria_df = pd.DataFrame(diphteria_data)

leprosy = pd.read_csv('leprosy.csv', index_col = 0)
leprosy_data = leprosy.copy()
leprosy_df = pd.DataFrame(leprosy_data)

malaria = pd.read_csv('malaria.csv', index_col = 0)
malaria_data = malaria.copy()
malaria_df = pd.DataFrame(malaria_data)

measles = pd.read_csv('measles.csv', index_col = 0)
measles_data = measles.copy()
measles_df = pd.DataFrame(measles_data)

mumps = pd.read_csv('mumps.csv', index_col = 0)
mumps_data = mumps.copy()
mumps_df = pd.DataFrame(mumps_data)

pertrussis = pd.read_csv('pertrussis.csv', index_col = 0)
pertrussis_data = pertrussis.copy()
pertrussis_df = pd.DataFrame(pertrussis_data)

polio = pd.read_csv('polio.csv', index_col = 0)
polio_data = polio.copy()
polio_df = pd.DataFrame(polio_data)

rubella = pd.read_csv('rubella.csv', index_col = 0)
rubella_data = rubella.copy()
rubella_df = pd.DataFrame(rubella_data)

tetanus = pd.read_csv('tetanus.csv', index_col = 0)
tetanus_data = tetanus.copy()
tetanus_df = pd.DataFrame(tetanus_data)

yellow_fever = pd.read_csv('yellow_fever.csv', index_col = 0)
yellow_fever_data = yellow_fever.copy()
yellow_fever_df = pd.DataFrame(yellow_fever_data)

cholera = pd.read_csv('cholera.csv', index_col = 0)
cholera_data = cholera.copy()
cholera_df = pd.DataFrame(cholera_data)

# %%
# Google Colab. Make sure the files are set to edit for everyone with the link.
import pandas as pd

# Files
url_diphteria = 'https://drive.google.com/file/d/1tpqXTGMZaI9rJaelwFTQsjazF6ZODbdn/view?usp=sharing'
path_diphteria = 'https://drive.google.com/uc?export=download&id='+url_diphteria.split("/")[-2]
diphteria = pd.read_csv(path_diphteria, index_col = 0)
diphteria_data = diphteria.copy()
diphteria_df = pd.DataFrame(diphteria_data)

url_leprosy = 'https://drive.google.com/file/d/1hmUF3kkOU2SWiz1Ctqwbji-k6dRC-yoz/view?usp=sharing'
path_leprosy = 'https://drive.google.com/uc?export=download&id='+url_leprosy.split("/")[-2]
leprosy = pd.read_csv(path_leprosy, index_col = 0)
leprosy_data = leprosy.copy()
leprosy_df = pd.DataFrame(leprosy_data)

url_malaria = 'https://drive.google.com/file/d/1hmUF3kkOU2SWiz1Ctqwbji-k6dRC-yoz/view?usp=sharing'
path_malaria = 'https://drive.google.com/uc?export=download&id='+url_malaria.split("/")[-2]
malaria = pd.read_csv(path_malaria, index_col = 0)
malaria_data = malaria.copy()
malaria_df = pd.DataFrame(malaria_data)

url_measles = 'https://drive.google.com/file/d/1GDHVrmX4A2HVoQpGBBlnfJLPwQanjMXZ/view?usp=sharing'
path_measles = 'https://drive.google.com/uc?export=download&id='+url_measles.split("/")[-2]
measles = pd.read_csv(path_measles, index_col = 0)
measles_data = measles.copy()
measles_df = pd.DataFrame(measles_data)

url_mumps = 'https://drive.google.com/file/d/13XIuC9b98aplOJXvWUWpGNcBWWbkCRd7/view?usp=sharing'
path_mumps = 'https://drive.google.com/uc?export=download&id='+url_mumps.split("/")[-2]
mumps = pd.read_csv(path_mumps, index_col = 0)
mumps_data = mumps.copy()
mumps_df = pd.DataFrame(mumps_data)

url_pertussis = 'https://drive.google.com/file/d/1J_olELNZQJqM-QfuBlCcNLcvp474DiOi/view?usp=sharing'
path_pertussis = 'https://drive.google.com/uc?export=download&id='+url_pertussis.split("/")[-2]
pertrussis = pd.read_csv(path_pertussis, index_col = 0)
pertrussis_data = pertrussis.copy()
pertrussis_df = pd.DataFrame(pertrussis_data)

url_polio = 'https://drive.google.com/file/d/13xhkDuSHP4tkXnfJPQsTcMmYgEgPj7V6/view?usp=sharing'
path_polio = 'https://drive.google.com/uc?export=download&id='+url_polio.split("/")[-2]
polio = pd.read_csv(path_polio, index_col = 0)
polio_data = polio.copy()
polio_df = pd.DataFrame(polio_data)

url_rubella = 'https://drive.google.com/file/d/1y9uX7mPU2xENauxvn9wOuS4DS8E1uxaL/view?usp=sharing'
path_rubella = 'https://drive.google.com/uc?export=download&id='+url_rubella.split("/")[-2]
rubella = pd.read_csv(path_rubella, index_col = 0)
rubella_data = rubella.copy()
rubella_df = pd.DataFrame(rubella_data)

url_tetanus = 'https://drive.google.com/file/d/1wIrjZnm_gGje3cxOMXqwxgiRHqsR9FRK/view?usp=sharing'
path_tetanus = 'https://drive.google.com/uc?export=download&id='+url_tetanus.split("/")[-2]
tetanus = pd.read_csv(path_tetanus, index_col = 0)
tetanus_data = tetanus.copy()
tetanus_df = pd.DataFrame(tetanus_data)

#url_yf = 'https://drive.google.com/file/d/1dCGHziFhaCoztuqpiQqUnzheUXE3Xz-U/view?usp=sharing'
#path_yellow_fever = 'https://drive.google.com/uc?export=download&id='+url_yf.split("/")[-2]
#yellow_fever = pd.read_csv(path_yellow_fever, index_col = 0)
#yellow_fever_data = yellow_fever.copy()
#yellow_fever_df = pd.DataFrame(yellow_fever_data)

url_cholera = 'https://drive.google.com/file/d/1JlQKIZ_N-MKbkRaPCkPBkCLtFHZhiUEu/view?usp=sharing'
path_cholera = 'https://drive.google.com/uc?export=download&id='+url_cholera.split("/")[-2]
cholera = pd.read_csv(path_cholera, index_col = 0)
cholera_data = cholera.copy()
cholera_df = pd.DataFrame(cholera_data)

# %%
#mumps_df.info()
#polio_df.info()
#measles_df.info()
#cholera_df.info()
#pertrussis_df.info()
#leprosy_df.info()
#tetanus_df.info()
#malaria_df.info()
#diphteria_df.info()
#rubella_df.info()
#yellow_fever_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8842 entries, 0 to 8841
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  8842 non-null   int64
#  1   IndicatorCode       8842 non-null   object
#  2   SpatialDimType      8842 non-null   object
#  3   SpatialDim          8842 non-null   object
#  4   ParentLocationCode  8241 non-null   object
#  5   TimeDimType         8842 non-null   object
#  6   ParentLocation      8241 non-null   object
#  7   TimeDim             8842 non-null   int64
#  8   Value               8842 non-null   object
#  9   NumericValue        8842 non-null   float64
#  10  Date                8842 non-null   object
#  11  TimeDimensionValue  8842 non-null   int64
#  12  TimeDimensionBegin  8842 non-null   object
#  13  TimeDimensionEnd    8842 non-null   object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.0+ MB

# %%
# Drop unusefull columns
diphteria_df = diphteria_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
mumps_df = mumps_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
polio_df = polio_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
measles_df = measles_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
cholera_df = cholera_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High'])
pertrussis_df = pertrussis_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
leprosy_df = leprosy_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
tetanus_df = tetanus_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
malaria_df = malaria_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
rubella_df = rubella_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
#yellow_fever_df = yellow_fever_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d0f3dce85fab> in <cell line: 2>()
#       1 # Drop unusefull columns
# ----> 2 diphteria_df = diphteria_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
#       3 mumps_df = mumps_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
#       4 polio_df = polio_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
#       5 measles_df = measles_df.drop(columns = ['Dim1Type', 'Dim1','Dim2Type','Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType','DataSourceDim', 'Low', 'High', 'Comments'])
#
# ...

# %%
# Add an adittional column with the name of the disease
diphteria_df['Name'] = 'diphteria'
mumps_df['Name'] = 'mumps'
polio_df['Name'] = 'poliomyelitis'
measles_df['Name'] = 'measles'
cholera_df['Name'] = 'cholera'
pertrussis_df['Name'] = 'pertussis'
leprosy_df['Name'] = 'leprosy'
tetanus_df['Name'] = 'tetanus'
malaria_df['Name'] = 'malaria'
rubella_df['Name'] = 'rubella'
yellow_fever_df['Name'] = 'yellow fever'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0d235f0547dc> in <cell line: 12>()
#      10 malaria_df['Name'] = 'malaria'
#      11 rubella_df['Name'] = 'rubella'
# ---> 12 yellow_fever_df['Name'] = 'yellow fever'
#
# NameError: name 'yellow_fever_df' is not defined

# %% [markdown]
# # Web-scrapping for additional information 🔦

# %%
# Add the name and code of the country
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3#ABW'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
soup.find_all(class_='monospaced')
soup.find_all(class_='monospaced')[366].get_text()
# Out:
# 'YMD'

# %%
# Extract the codes
country_code = []
i = 0
while i < 249:
    code = soup.find_all(class_='monospaced')[i].get_text()
    country_code.append(code)
    i += 1

# %%
country_code[248]
#len(country_code)
# Out:
# 'ZWE'

# %%
# Extract the names
country_name = []
i = 0
while i < 249:
    name = soup.find_all(class_='monospaced')[i].find_next().get_text()
    country_name.append(name)
    i +=1

# %%
country_name[248]
#len(country_name)
# Out:
# 'Zimbabwe'

# %%
country_codes_df = pd.DataFrame({'code':country_code, 'country':country_name})
#country_codes_df

# %%
# Store the country_codes as .csv for later use
country_codes_df.to_csv('country_codes_.csv', index = 1)

# %% [markdown]
# # Creating a DataFrame

# %%
# Concatenating
diseases_stats = [diphteria_df,mumps_df,polio_df,measles_df,cholera_df,pertrussis_df,leprosy_df,tetanus_df,malaria_df,rubella_df,yellow_fever_df]
diseases_stats_df = pd.concat(diseases_stats, ignore_index=1)

# %%
diseases_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63209 entries, 0 to 63208
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  63209 non-null  int64
#  1   IndicatorCode       63209 non-null  object
#  2   SpatialDimType      63209 non-null  object
#  3   SpatialDim          63209 non-null  object
#  4   ParentLocationCode  59284 non-null  object
#  5   TimeDimType         63209 non-null  object
#  6   ParentLocation      59284 non-null  object
#  7   TimeDim             63209 non-null  int64
#  8   Value               63209 non-null  object
#  9   NumericValue        59920 non-null  float64
#  10  Date                63209 non-null  object
#  11  TimeDimensionValue  63209 non-null  int64
#  12  TimeDimensionBegin  63209 non-null  object
#  13  TimeDimensionEnd    63209 non-null  object
#  14  Name                63209 non-null  object
# ...

# %%
# Local
# Merging
country_codes_df = pd.read_csv('country_codes_.csv', index_col = 0)
diseases_stats_df = diseases_stats_df.merge(country_codes_df, left_on = 'SpatialDim', right_on = 'code' )

# %%
# Google Colab. Make sure file is set to edit for everyone with the link
# Merging
url_country_codes = 'https://drive.google.com/file/d/1kabTFQoZk_6DAdH7YxxtdJ7XEi7Yelxj/view?usp=sharing'
path_country_codes = 'https://drive.google.com/uc?export=download&id='+url_country_codes.split("/")[-2]
country_codes_df = pd.read_csv(path_country_codes, index_col = 0)
diseases_stats_df = diseases_stats_df.merge(country_codes_df, left_on = 'SpatialDim', right_on = 'code' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cca0e69b86a0> in <cell line: 6>()
#       4 path_country_codes = 'https://drive.google.com/uc?export=download&id='+url_country_codes.split("/")[-2]
#       5 country_codes_df = pd.read_csv(path_country_codes, index_col = 0)
# ----> 6 diseases_stats_df = diseases_stats_df.merge(country_codes_df, left_on = 'SpatialDim', right_on = 'code' )
#
# NameError: name 'diseases_stats_df' is not defined

# %%
# Dropping unusefull columns
diseases_stats_df = diseases_stats_df.drop(columns = ['Id', 'IndicatorCode','SpatialDimType','SpatialDim','ParentLocationCode','TimeDimType','Value','Date','TimeDimensionValue','Comments'])

# %%
diseases_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59769 entries, 0 to 59768
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ParentLocation      59284 non-null  object
#  1   TimeDim             59769 non-null  int64
#  2   NumericValue        56484 non-null  float64
#  3   TimeDimensionBegin  59769 non-null  object
#  4   TimeDimensionEnd    59769 non-null  object
#  5   Name                59769 non-null  object
#  6   code                59769 non-null  object
#  7   country             59769 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.6+ MB

# %%
diseases_stats_df.to_csv('diseases_stats.csv', index = 0)

# %% [markdown]
# # Creating tables 🤧

# %% [markdown]
# Now that we have a clean and usefull file (*diseases_stats.csv*) we can use this to create tables for our MySQL Database

# %%
# Local
import pandas as pd
# Use the concatenated, clean file
diseases_stats = pd.read_csv('diseases_stats.csv')
diseases_stats_data = diseases_stats.copy()
diseases_stats_df = pd.DataFrame(diseases_stats_data)

# %%
# Google Colab. Make sure the file is set to edit for everyone with the link
import pandas as pd
# Use the concatenated, clean file
url_diseases_stats = 'https://drive.google.com/file/d/19i7T3RGLZL-Z3HnXNlkECq_bpnst0J5U/view?usp=sharing'
path_diseases_stats = 'https://drive.google.com/uc?export=download&id='+url_diseases_stats.split("/")[-2]
diseases_stats = pd.read_csv(path_diseases_stats)
diseases_stats_data = diseases_stats.copy()
diseases_stats_df = pd.DataFrame(diseases_stats_data)

# %%
diseases_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59769 entries, 0 to 59768
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ParentLocation      59284 non-null  object
#  1   TimeDim             59769 non-null  int64
#  2   NumericValue        56484 non-null  float64
#  3   TimeDimensionBegin  59769 non-null  object
#  4   TimeDimensionEnd    59769 non-null  object
#  5   Name                59769 non-null  object
#  6   code                59769 non-null  object
#  7   country             59769 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.6+ MB

# %%
# Store useful columns of the diseases_stats_df as series. We are goingo to use this later.

diseases_names = pd.Series(diseases_stats_df.Name) # Name of the disease
diseases_years = pd.Series(diseases_stats_df.TimeDim) # Corresponding year of the statistic
diseases_cases = pd.Series(diseases_stats_df.NumericValue) # Number of cases
diseases_locations_codes = pd.Series(diseases_stats_df.code) # ISO 3 letter code of the country
diseases_locations_countries = pd.Series(diseases_stats_df.country) # Name of the country
diseases_continents = pd.Series(diseases_stats_df.ParentLocation) # Name of the continent

# %%
# The colums we stored as series are now going to be stored in dictionaries. The keys of the dictionaries are the same names as the columns in the tables in the MySQL Database
diseases_stats_clean_df = pd.DataFrame({'disease_name':diseases_names,
                              'disease_stat_year':diseases_years,
                              'disease_stat_cases':diseases_cases,
                              'country_iso_code':diseases_locations_codes,
                              'country_name':diseases_locations_countries,
                              'country_continent_short':diseases_continents})

# %%
diseases_stats_clean_df
# Out:
#       disease_name  disease_stat_year  disease_stat_cases country_iso_code  \
# 0        diphteria               2000                12.0              MDG
# 1        diphteria               2011                 5.0              MDG
# 2        diphteria               1986               288.0              MDG
# 3        diphteria               2001                12.0              MDG
# 4        diphteria               1987               174.0              MDG
# ...            ...                ...                 ...              ...
# 59764      malaria               2002              3661.0              GUF
# 59765      malaria               2003              3839.0              GUF
# 59766      malaria               2014               448.0              GUF
# 59767      malaria               2011              1209.0              GUF
# 59768      malaria               2009              3462.0              GUF
#
#         country_name country_continent_short
# ...

# %%
diseases_unique = diseases_stats_clean_df['disease_name'].unique()
diseases_unique
# Out:
# array(['diphteria', 'mumps', 'poliomyelitis', 'measles', 'cholera',
#        'pertussis', 'leprosy', 'tetanus', 'malaria', 'rubella',
#        'yellow fever'], dtype=object)

# %%
# Foundation for diseases table
diseases_unique = diseases_stats_clean_df['disease_name'].unique()
diseases_incubation_min = [2,7,4,10,2,4,5,3,10,12,3]
diseases_incubation_min_unit = ['days','days','days','days','hours','days','years','days','days','days','days']
diseases_incubation_max = [5,25,35,14,5,21,20,21,15,23,6]
diseases_incubation_max_unit = ['days','days','days','days','days','days','years','days','days','days','days']
diseases_contagious_period = [2,7,10,8,7,4,'continuos','noninfectious','noninfectious',14, 'noninfectious']
diseases_contagious_period_unit = ['weeks','days','days','days','days', 'weeks','NaN','NaN','NaN','days','NaN']
diseases_cause = ['Corynebacterium diphtheriae','mumps virus','poliovirus','measles virus','Vibrio cholerae','Bordetella pertussis','Mycobacterium leprae','Clostridium tetani','Plasmodium','rubella virus','Yellow fever virus']
diseases_transmission = ['respiratory droplets','respiratory droplets or saliva, as well as contact','fecal-oral route','respiratory droplets', 'ingestion of contaminated food or water','respiratory droplets','prolonged close contact','bacteria entering the body through wounds or cuts','bites of infected female Anopheles mosquitoes','respiratory droplets or direct contact','Yellow fever virus spread by mosquitos' ]
diseases_df = pd.DataFrame({'disease_name':diseases_unique,
                            'disease_cause': diseases_cause,
                            'disease_transmission': diseases_transmission,
                           'disease_incubation_period_min':diseases_incubation_min,
                           'disease_incubation_period_min_unit':diseases_incubation_min_unit,
                           'disease_incubation_period_max':diseases_incubation_max,
                           'disease_incubation_period_max_unit':diseases_incubation_max_unit,
                           'disease_contagious_period':diseases_contagious_period,
                           'disease_contagious_period_unit':diseases_contagious_period_unit})

# %%
# Store the DataFrame for further use
diseases_stats_clean_df.to_csv('diseases_stats_clean.csv', index = 0)

# %% [markdown]
# # Connecting to MySQL 🔗

# %% [markdown]
# Now we can start the database in MySQL.
# </br>The script looks like this:
# </br>-- Create the initial Database for the WBS_DS_29 Project. It will contain five tables
# </br>DROP DATABASE IF EXISTS sql_database_wbs_ds_29_project;
# </br>CREATE DATABASE sql_database_wbs_ds_29_project;
# </br>USE sql_database_wbs_ds_29_project;
# </br>CREATE TABLE diseases (
# </br>	disease_id INT AUTO_INCREMENT,
# </br>    disease_name VARCHAR (100) NOT NULL,
# </br>    disease_cause VARCHAR (100),
# </br>    disease_transmission VARCHAR (100),
# </br>    disease_incubation_period_min INT,
# </br>    disease_incubation_period_min_unit VARCHAR (50),
# </br>    disease_incubation_period_max INT,
# </br>    disease_incubation_period_max_unit VARCHAR (50),
# </br>    disease_contagious_period VARCHAR (50),
# </br>    disease_contagious_period_unit VARCHAR (50),
# </br>    PRIMARY KEY (disease_id)
# </br>);
# </br>CREATE TABLE diseases_stats_per_countries (
# </br>	disease_stat_id INT AUTO_INCREMENT,
# </br>    disease_stat_year INT NOT NULL,
# </br>    disease_stat_cases INT,
# </br>    country_id INT,
# </br>    disease_id INT,
# </br>    PRIMARY KEY(disease_stat_id),
# </br>    FOREIGN KEY (country_id) REFERENCES countries(country_id),
# </br>    FOREIGN KEY (disease_id) REFERENCES diseases(disease_id)
# </br>);

# %%
# Locally
# sqlalchemy will be the library to use for the connection
import sqlalchemy
from sql_connection import connection_string # This is the script I created with the information for the connection.

# %%
# Google Colab
import sqlalchemy
schema = "sql_workshop"
host = "127.0.0.1"
user = "root"
password = MySQL_pass
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
# Adding to the table diseases
diseases_df.to_sql( 'diseases',
                   if_exists = 'append',
                   con = connection_string,
                   index = 0
)
# Out:
# 10

# %% [markdown]
# As we can see from the screen shot, the connection was establish and the table *diseases* was filled.
# ![Screenshot Connection Pyhton to MySQL.png](attachment:c94fdb55-94bd-449b-9e65-9976c1e180f6.png)
#
# Now that we have a first working connection, let's try mixing the table containing statistical information on the diseases.

# %% [markdown]
# # Linking other tables 🖇️

# %%
# Local
# File
diseases_stats_clean = pd.read_csv('diseases_stats_clean.csv')
diseases_stats_clean_data = diseases_stats_clean.copy()
diseases_stats_clean_df = pd.DataFrame(diseases_stats_clean_data)

# %%
# Google Colab. Make sure file is set to edit with everyone with the link
url_diseases_stats_clean = 'https://drive.google.com/file/d/1htH1NnMhsQGiJkZIDeIEQ-r7sHQoJupa/view?usp=sharing'
path_diseases_stats_clean = 'https://drive.google.com/uc?export=download&id='+url_diseases_stats_clean.split("/")[-2]
diseases_stats_clean = pd.read_csv(path_diseases_stats_clean)
diseases_stats_clean_data = diseases_stats_clean.copy()
diseases_stats_clean_df = pd.DataFrame(diseases_stats_clean_data)

# %%
diseases_stats_df = diseases_stats_clean_df

# %%
diseases_stats_df
# Out:
#       disease_name  disease_stat_year  disease_stat_cases country_iso_code  \
# 0        diphteria               2000                12.0              MDG
# 1        diphteria               2011                 5.0              MDG
# 2        diphteria               1986               288.0              MDG
# 3        diphteria               2001                12.0              MDG
# 4        diphteria               1987               174.0              MDG
# ...            ...                ...                 ...              ...
# 59764      malaria               2002              3661.0              GUF
# 59765      malaria               2003              3839.0              GUF
# 59766      malaria               2014               448.0              GUF
# 59767      malaria               2011              1209.0              GUF
# 59768      malaria               2009              3462.0              GUF
#
#         country_name country_continent_short
# ...

# %%
# Read the contect of the diseases table in MySQL and store it
diseases_from_sql = pd.read_sql("diseases", con=connection_string) # Conection to SQL

# %% [markdown]
# As we can see, the *diseases_stats_df* has no unique diseases and has the statistical information. The *diseases* table in MySQL has unique values (i.e. Id) for each unique disease as well as information related to each disease. If we merge both tables we will have the information we need for the *diseases_stats_per_countries* table. The foreign key will then be the Id of the disease and later on from the country as well.

# %%
# Merge by the disease_name
diseases_stats_df = diseases_stats_df.merge(diseases_from_sql, on = 'disease_name', how = 'left')

# %%
diseases_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59769 entries, 0 to 59768
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   disease_name                        59769 non-null  object
#  1   disease_stat_year                   59769 non-null  int64
#  2   disease_stat_cases                  56484 non-null  float64
#  3   country_iso_code                    59769 non-null  object
#  4   country_name                        59769 non-null  object
#  5   country_continent_short             59284 non-null  object
#  6   disease_id                          55914 non-null  float64
#  7   disease_cause                       55914 non-null  object
#  8   disease_transmission                55914 non-null  object
#  9   disease_incubation_period_min       55914 non-null  float64
#  10  disease_incubation_period_min_unit  55914 non-null  object
# ...

# %% [markdown]
# Perfect, now we can drop the columns that are not relevant to the *diseases_stats_per_countries* table in MySQL

# %%
diseases_stats_df = diseases_stats_df.drop(columns=['disease_name','disease_cause','disease_transmission','disease_incubation_period_min','disease_incubation_period_min_unit','disease_incubation_period_max','disease_incubation_period_max_unit','disease_contagious_period','disease_contagious_period_unit'])

# %% [markdown]
# And now we upload the information to the *diseases_stats_per_countries* table in MySQL

# %%
# Adding to the table diseases_stats_per_countries
diseases_stats_df.to_sql( 'diseases_stats_per_countries',
                   if_exists = 'append',
                   con = connection_string,
                   index = 0
)
# Out:
# 59769

# %% [markdown]
# # Success :)
# ![Screenshot Connection Pyhton to MySQL_2.png](attachment:b6415104-20d1-41ec-8c4f-d2b92ebf80a2.png)
